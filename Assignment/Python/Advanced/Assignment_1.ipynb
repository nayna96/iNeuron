# %% [markdown]
# ### Q1. What is the purpose of Python's OOP?

# %% [markdown]
# **Ans:**

# %% [markdown]
# - OOP is to design the program using classes and objects.
# - OOPs concept focuses on writing the reusable code.
# - OOPs makes development and maintenance easier.
# - OOPs provides data hiding.

# %% [markdown]
# ### Q2. Where does an inheritance search look for an attribute?

# %% [markdown]
# **Ans:**

# %% [markdown]
# The inheritance search looks for an attribute in its superclass.

# %% [markdown]
# ### Q3. How do you distinguish between a class object and an instance object?

# %% [markdown]
# **Ans:**

# %% [markdown]
# The object of pre-defined classes is called class object.

# %%
type([1,2,3])
# Out:
# list

# %% [markdown]
# It is an instance object.

# %% [markdown]
# The object of user defined classes is called class object.

# %%
class Test:
    pass

t = Test()

# %% [markdown]
# Here, t is a class object

# %% [markdown]
# ### Q4. What makes the first argument in a class’s method function special?

# %% [markdown]
# **Ans:**

# %% [markdown]
# The first argument in class's method function is self.It is a reference to the current instance of the class. In the init method, self refers to the newly created object; in other class methods, it refers to the instance whose method was called.

# %% [markdown]
# ### Q5. What is the purpose of the __init__ method?

# %% [markdown]
# **Ans:**

# %% [markdown]
# The purpose of the \_\_init\_\_ method in a class definition if to set the instance variables to initial values

# %%
class Person:
    def __init__(self, name):
        self.name = name
        
p = Person("N")
p.name
# Out:
# 'N'

# %% [markdown]
# ### Q6. What is the process for creating a class instance?

# %% [markdown]
# **Ans:**

# %% [markdown]
# We can use the class named Test to create objects-

# %%
class Test:
    x = 5

t = Test()
print(t.x)
# Out:
# 5

# %% [markdown]
# ### Q7. What is the process for creating a class?

# %% [markdown]
# **Ans:**

# %% [markdown]
# To create a class, we use the keyword class followed by class name.

# %%
class Test:
    pass

# %% [markdown]
# ### Q8. How would you define the superclasses of a class?

# %% [markdown]
# **Ans:**

# %% [markdown]
# - The class from which a class inherits is called the parent or superclass. A class which inherits from a superclass is called a subclass, also called child class.
# - The superclass of a class is defined by passing the subclass as parameter to the superclass.

# %%
class Person:
    def __init__(self, name):
        self.name = name
    
    def printname(self):
        print(self.name)

class Student(Person):
    pass

x = Student("N")
x.printname()
# Out:
# N
