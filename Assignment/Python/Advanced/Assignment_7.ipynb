# %% [markdown]
# ### Q1. What is the purpose of the try statement?

# %% [markdown]
# **Ans:**

# %% [markdown]
# The try statement allows you to define a block of code to be tested for errors while it is being executed. The catch statement allows you to define a block of code to be executed, if an error occurs in the try block.

# %%
try:
    a = 5
    b = 0
    a / b
except Exception as e:
    print(e)
# Out:
# division by zero

# %% [markdown]
# ### Q2. What are the two most popular try statement variations?

# %% [markdown]
# **Ans:**

# %%
try:
    a = 5
    b = 5
    c = a / b
except Exception as e:
    print(e)
else:
    print(c)
# Out:
# 1.0

# %%
try:
    k = 5 / 0 
    print(k)
except Exception as e:
    print(e)
finally:
    print('This is always executed')
# Out:
# division by zero
# This is always executed

# %% [markdown]
# ### Q3. What is the purpose of the raise statement?

# %% [markdown]
# **Ans:**

# %% [markdown]
# raise allows you to throw an exception at any time. assert enables you to verify if a certain condition is met and throw an exception if it isn't. In the try clause, all statements are executed until an exception is encountered. except is used to catch and handle the exception(s) that are encountered in the try clause.

# %%
x = -1

if x < 0:
    raise Exception("Negative number")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-e796f06a4a8f> in <module>
#       2
#       3 if x < 0:
# ----> 4     raise Exception("Negative number")
#
# Exception: Negative number

# %% [markdown]
# ### Q4. What does the assert statement do, and what other statement is it like?

# %% [markdown]
# **Ans:**

# %% [markdown]
# Assert statement takes an expression and optional message. assert statement is used to check types, values of argument and the output of the function. assert statement is used as debugging tool as it halts the program at the point where an error occurs.

# %%
a = 4
b = 0

print ("The value of a / b is : ")
assert b != 0, "Divide by 0 error"
print (a / b)
# Out:
# The value of a / b is :
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-ea1c25b66f7f> in <module>
#       3
#       4 print ("The value of a / b is : ")
# ----> 5 assert b != 0, "Divide by 0 error"
#       6 print (a / b)
#
# AssertionError: Divide by 0 error

# %% [markdown]
# ### Q5. What is the purpose of the with/as argument, and what other statement is it like?

# %% [markdown]
# **Ans:**

# %% [markdown]
# as keyword is used to print the exact exception

# %%
try:
    l = [1,2,3,4,5]
    l[5]
except Exception as e:
    print(e)
# Out:
# list index out of range
