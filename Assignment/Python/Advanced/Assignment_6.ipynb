# %% [markdown]
# ### Q1. Describe three applications for exception processing.

# %% [markdown]
# **Ans:**

# %% [markdown]
# - Exception handling is important because it helps maintain the normal, desired flow of the program even when unexpected events occur.
# - If exceptions are not handled, programs may crash or requests may fail.
# - Exception handling allows to separate error-handling code from normal code.
# - Exceptions helps to remind of what the program expects.
# - It clarifies the code and enhances readability.

# %% [markdown]
# ### Q2. What happens if you don't do something extra to treat an exception?

# %% [markdown]
# **Ans:**

# %% [markdown]
# When an exception occurred, if you don't treat it, the program terminates abruptly and the code past the line that caused the exception will not get executed.

# %%
a = 10
b = 0    
print(a / b)
print("Something")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-9e28a656555c> in <module>
#       1 a = 10
#       2 b = 0
# ----> 3 print(a / b)
#       4 print("Something")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Q3. What are your options for recovering from an exception in your script?

# %% [markdown]
# **Ans:**

# %% [markdown]
# For recovering from an exception, we use try and except block.
#
# If the Python program contains suspicious code that may throw the exception, we must place that code in the try block.
#
# The try block must be followed with the except statement, which contains a block of code that will be executed if there is some exception in the try block.

# %%
try:  
    a = int(input("A: "))    
    b = int(input("B: "))    
    print(a/b)  
except Exception as e:  
    print(e)
# Out:
# A: 5
# B: 0
# division by zero

# %% [markdown]
# ### Q4. Describe two methods for triggering exceptions in your script.

# %% [markdown]
# **Ans:**

# %% [markdown]
# **Raise**

# %% [markdown]
# An exception can be raised forcefully by using the raise clause in Python. It is useful in in that scenario where we need to raise an exception to stop the execution of the program.

# %%
try:  
    num = int(input("Enter a positive integer: "))  
    if(num <= 0):  
        raise ValueError("That is  a negative number!")  
except ValueError as e:  
    print(e)
# Out:
# Enter a positive integer: -1
# That is  a negative number!

# %% [markdown]
# **Assert**

# %% [markdown]
# The assert keyword is used when debugging code.The assert keyword lets us test if a condition in our code returns True, if not, the program will raise an AssertionError.

# %%
try:
    y = 0
    assert y != 0, "Invalid Operation"

except Exception as e:
    print(e)
# Out:
# Invalid Operation

# %% [markdown]
# ### Q5. Identify two methods for specifying actions to be executed at termination time, regardless of whether or not an exception exists.

# %% [markdown]
# **Ans:**

# %% [markdown]
# **Finally**

# %% [markdown]
# Python provides a keyword finally, which is always executed after try and except blocks. The finally block always executes after normal termination of try block or after try block terminates due to some exception.

# %%
try:
    k = 5 / 0 
    print(k)

except Exception as e:
    print(e)
finally:
    print('This is always executed')
# Out:
# division by zero
# This is always executed
