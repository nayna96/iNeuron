# %% [markdown]
# ### 1.	Write a Python program to Extract Unique values dictionary values?

# %% [markdown]
# **Ans:**

# %%
d = {'a' : 15, 'b' : 10, 'c' : 15, 'd' : 10}
set(list(d.values()))
# Out:
# {10, 15}

# %% [markdown]
# ### 2.	Write a Python program to find the sum of all items in a dictionary?

# %% [markdown]
# **Ans:**

# %%
dict_ = {'a': 100, 'b':200, 'c':300}
sum(dict_.values())
# Out:
# 600

# %% [markdown]
# ### 3.	Write a Python program to Merging two Dictionaries?

# %% [markdown]
# **Ans:**

# %%
dict1 = {'a': 1, 'b': 2}
dict2 = {'c': 3, 'd': 4}

dict1.update(dict2)

dict1
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# ### 4.	Write a Python program to convert key-values list to flat dictionary?

# %% [markdown]
# **Ans:**

# %%
from itertools import product

dict_ = {'letters' : ['a', 'b', 'c'],
            'numbers' : [1, 2, 3]}

print(dict_)

res = dict(zip(dict_['letters'], dict_['numbers']))

print("Flattened dictionary : " + str(res))
# Out:
# {'letters': ['a', 'b', 'c'], 'numbers': [1, 2, 3]}
# Flattened dictionary : {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# ### 5.	Write a Python program to insertion at the beginning in OrderedDict?

# %% [markdown]
# **Ans:**

# %%
from collections import OrderedDict

dict_ = OrderedDict([('a', '1'), ('b', '2')])

dict_.update({'c':'3'})
dict_.move_to_end('c', last = False)

dict_
# Out:
# OrderedDict([('c', '3'), ('a', '1'), ('b', '2')])

# %% [markdown]
# ### 6.	Write a Python program to check order of character in string using OrderedDict()?

# %% [markdown]
# **Ans:**

# %%
def checkOrder(string, pattern):
    dict_ = OrderedDict.fromkeys(string)

    ptrlen = 0
    for key,value in dict_.items():
        if (key == pattern[ptrlen]):
            ptrlen = ptrlen + 1

        if (ptrlen == (len(pattern))):
            return 'true'

    return 'false'

input = 'Python code'
pattern = 'Pon'
print (checkOrder(input,pattern))
# Out:
# true

# %% [markdown]
# ### 7.	Write a Python program to sort Python Dictionaries by Key or Value?

# %% [markdown]
# **Ans:**

# %%
dict_ ={"a":12, "z":76, "o":1, "d":4, "s":19}

# %% [markdown]
# **Sort by key**

# %%
for i in sorted (dict_.keys()) :
    print ((i, dict_[i]))
# Out:
# ('a', 12)
# ('d', 4)
# ('o', 1)
# ('s', 19)
# ('z', 76)

# %% [markdown]
# **Sort by value**

# %%
for i in sorted(dict_, key=dict_.get):
    print ((i, dict_[i]))
# Out:
# ('o', 1)
# ('d', 4)
# ('a', 12)
# ('s', 19)
# ('z', 76)
