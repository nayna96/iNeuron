# %% [markdown]
# ### 1. What exactly is []?

# %% [markdown]
# [] is a empty list which is a list value that contains no items. This is similar to how '' is the empty string value.<br>
# Lists are used to store multiple items in a single variable. We can store of any data types in a list.

# %%
l = [1, "abc", True, 9.0, [2,3,4], {4,5,6}, (4,3,8)]
print(l)
# Out:
# [1, 'abc', True, 9.0, [2, 3, 4], {4, 5, 6}, (4, 3, 8)]

# %% [markdown]
# ### 2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %%
spam = [2,4,6,8,10]

# %%
spam.insert(2, "hello")

# %%
spam
# Out:
# [2, 4, 'hello', 6, 8, 10]

# %% [markdown]
# ### Q. Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.**

# %%
spam = ['a','b','c','d']

# %% [markdown]
# ### 3. What is the value of spam[int(int('3' * 2) / 11)]?

# %% [markdown]
# '3' * 2 = '33'<br>
# int('3' * 2)/11 = int('33')/11 = 3.0<br>
# int(int('3' * 2)/11) = int(3.0)<br>
# spam[int(int('3' * 2)/11)] = spam[3] = 'd'<br>

# %%
spam[int(int('3' * 2) / 11)]
# Out:
# 'd'

# %% [markdown]
# ### 4. What is the value of spam[-1]?

# %% [markdown]
# spam[-1] will give the last element i.e 'd'

# %%
spam[-1]
# Out:
# 'd'

# %% [markdown]
# ### 5. What is the value of spam[:2]?

# %% [markdown]
# spam[:2] will give element present upto 1st index i.e. ['a','b']

# %%
spam[:2]
# Out:
# ['a', 'b']

# %% [markdown]
# ### Q. Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.

# %%
bacon = [3.14, 'cat', 11, 'cat', True]

# %% [markdown]
# ### 6. What is the value of bacon.index('cat')?

# %% [markdown]
# It will give the index of first occurence of cat

# %%
bacon.index('cat')
# Out:
# 1

# %% [markdown]
# ### 7. How does bacon.append(99) change the look of the list value in bacon?

# %% [markdown]
# It will add 99 at the end of the list

# %%
bacon.append(99)

# %%
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# ### 8. How does bacon.remove('cat') change the look of the list meaning in bacon?

# %% [markdown]
# It removes first occurence of cat

# %%
bacon.remove('cat')

# %%
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# ### 9. What are the list concatenation and list replication operators?

# %% [markdown]
# The operator for list concatenation is +, while the operator for replication is *. (This is the same as for strings.)

# %% [markdown]
# **Concatenation**

# %%
[1,2,3,4] + [5,6,7,8]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %% [markdown]
# **Replication**

# %%
[1,2,3,4] * 2
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %% [markdown]
# ### 10. What is difference between the list methods append() and insert()?

# %% [markdown]
# append() always adds the element at the end of the list

# %%
l = [1,2,3,4]

# %%
l.append(5)

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# In insert() we can specify in which index we want to insert the element

# %%
l = [1,3,4,5]

# %%
l.insert(1, 2)

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### 11. What are the two methods for removing items from a list?

# %%
l = [1,2,3,4,5]
l.remove(1)
print(l)
# Out:
# [2, 3, 4, 5]

# %%
l = [1,2,3,4,5]
l.pop(1)
print(l)
# Out:
# [1, 3, 4, 5]

# %%
l = [1,2,3,4,5]
del l[0]
print(l)
# Out:
# [2, 3, 4, 5]

# %%
l = [1,2,3,4,5]
l.clear()
print(l)
# Out:
# []

# %% [markdown]
# ### 12. Describe how list values and string values are identical.

# %% [markdown]
# Both lists and strings can be passed to len(), have indexes and slices, be used in for loops, be concatenated or replicated, and be used with the in and not in operators.

# %% [markdown]
# ### 13. What's the difference between tuples and lists?

# %% [markdown]
# List is mutable, whereas a tuple is immutable. This means that lists can be changed, and tuples cannot be changed.

# %% [markdown]
# **List**

# %%
l = [1,2,3,4]

# %%
l[0] = 5
l
# Out:
# [5, 2, 3, 4]

# %% [markdown]
# **Tuple**

# %%
t = (1,2,3,4)

# %%
t[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-6dd06f73cec4> in <module>
# ----> 1 t[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### 14. How do you type a tuple value that only contains the integer 42?

# %%
(42,)
# Out:
# (42,)

# %% [markdown]
# ### 15. How do you get a list value's tuple form? How do you get a tuple value's list form?

# %%
l = [1,2,3,4]

# %%
tuple(l)
# Out:
# (1, 2, 3, 4)

# %%
t = (1,2,3,4)

# %%
list(t)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### 16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

# %% [markdown]
# They contain references to list values.

# %% [markdown]
# ### 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %%
import copy
li1 = [1, 2, [3,5], 4] 
print("Original list: {}".format(li1))
# Out:
# Original list: [1, 2, [3, 5], 4]

# %% [markdown]
# **copy.deepcopy()**

# %% [markdown]
# deepcopy() creates new object and does real copying of original object to new one. Changing new deepcopied object doesn't affect original object.

# %%
import copy

result_A = [[90, 85, 82], [72, 88, 90]] 
result_B = copy.deepcopy(result_A) 
result_B[0][0] = 30

print("Original List: ")
print(result_A)
print("Deep Copy:")
print(result_B)
# Out:
# Original List:
# [[90, 85, 82], [72, 88, 90]]
# Deep Copy:
# [[30, 85, 82], [72, 88, 90]]

# %% [markdown]
# **copy.copy()**

# %% [markdown]
# copy() create reference to original object. If we change copied object it also changes the original object

# %%
import copy

result_A = [[90, 85, 82], [72, 88, 90]] 
result_B = copy.copy(result_A) 
result_B[0][0] = 30

print("Original List: ")
print(result_A)
print("Shallow Copy:")
print(result_B)
# Out:
# Original List:
# [[30, 85, 82], [72, 88, 90]]
# Shallow Copy:
# [[30, 85, 82], [72, 88, 90]]
