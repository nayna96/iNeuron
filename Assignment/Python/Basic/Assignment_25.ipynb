# %% [markdown]
# ### 1) What is the difference between enclosing a list comprehension in square brackets and parentheses?

# %% [markdown]
# **Ans**

# %% [markdown]
# Enclosing a list comprehension in square brackets gives us list as ouput whhile using parantheses gives generator as output

# %%
l = [i for i in range(10)]

# %%
type(l)
# Out:
# list

# %%
g = (i for i in range(10))

# %%
type(g)
# Out:
# generator

# %% [markdown]
# ### 2) What is the relationship between generators and iterators?

# %% [markdown]
# **Ans**

# %%
import collections,types

# %% [markdown]
# **a. A python generator is an iterator**<br>
# Generator in python is a subclass of Iterator. To prove this, we use the issubclass() function.

# %%
issubclass(types.GeneratorType,collections.Iterator)
# Out:
# <ipython-input-6-507df196606e>:1: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   issubclass(types.GeneratorType,collections.Iterator)
# True

# %%
issubclass(collections.Generator,collections.Iterator)
# Out:
# <ipython-input-7-7e6f313e6ba0>:1: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   issubclass(collections.Generator,collections.Iterator)
# True

# %%
issubclass(collections.Iterator,types.GeneratorType)
# Out:
# False

# %% [markdown]
# **b. Python iterator is an iterable**<br>
# Iterator in python is a subclass of Iterable.

# %%
issubclass(collections.Iterator,collections.Iterable)
# Out:
# <ipython-input-9-b6f210c7aec1>:1: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#   issubclass(collections.Iterator,collections.Iterable)
# True

# %% [markdown]
# ### 3) What are the signs that a function is a generator function?

# %% [markdown]
# **Ans**

# %% [markdown]
# If it contains a yield keyword instead of return, it is a generator function

# %%
def simpleGeneratorFun(): 
    yield 1
    yield 2
    yield 3

for value in simpleGeneratorFun(): 
    print(value)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### 4) What is the purpose of a yield statement?

# %% [markdown]
# **Ans**

# %% [markdown]
# yield is used to return from a function without destroying the states of its local variable and when the function is called, the execution starts from the last yield statement.

# %%
def nextSquare(): 
    i = 1; 

    while True: 
        yield i*i
        i += 1  

for num in nextSquare(): 
    if num > 100: 
        break
    print(num)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %% [markdown]
# ### 5) What is the relationship between map calls and list comprehensions? Make a comparison and contrast between the two.

# %% [markdown]
# **Ans**

# %% [markdown]
# - List comprehension is more concise and easier to read as compared to map.

# %% [markdown]
# - List comprehension allows filtering. In map, we have no such facility.<br>

# %% [markdown]
# **Example:**

# %%
[n for n in range(10) if n%2 == 0]
# Out:
# [0, 2, 4, 6, 8]

# %% [markdown]
# - List comprehension are used when a list of results is required as map only returns a map object and does not return any list.

# %% [markdown]
# - List comprehension is faster than map when we need to evaluate expressions that are too long or complicated to express

# %% [markdown]
# - Map is faster in case of calling an already defined function (as no lambda is required).

# %% [markdown]
# **Comparing Execution Time:**

# %% [markdown]
# **List comprehension**

# %%
import timeit

# %%
x = timeit.timeit ('[x for x in range(100)]', number = 999999)
print(x)
# Out:
# 2.8638032000000004

# %% [markdown]
# **Map without lambda**

# %%
s = 'def func() : print(i)'
y = timeit.timeit('map(func, range(100))', number = 999999, setup = s)
print(y)
# Out:
# 0.29757560000000005

# %% [markdown]
# From the above Example, we can conclude that map performs better than list comprehension when a function is defined already.

# %% [markdown]
# **List comprehension**

# %%
y = timeit.timeit('[a+2 for a in range(1000)]', number = 999999)
print(y)
# Out:
# 55.354076500000005

# %% [markdown]
# **Map with lambda**

# %%
x = timeit.timeit('map(lambda a: a+2, range(1000))', number = 999999)
print(x)
# Out:
# 0.40350689999999645

# %% [markdown]
# From the above code, we can observe that map still works better than list comprehension.

# %% [markdown]
# Note: There are cases when list comprehension can perform better than map where expressions are too long and complex.
