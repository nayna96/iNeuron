# %% [markdown]
# ### 1. Add the current date to the text file today.txt as a string.

# %% [markdown]
# **Ans:**

# %%
from datetime import date

f1 = open('today.txt', mode='w+')
f1.write(str(date.today().strftime('%m/%d/%Y')))
# Out:
# 10

# %% [markdown]
# ### 2. Read the text file today.txt into the string today_string

# %% [markdown]
# **Ans:**

# %%
f1.seek(0)
today_string = f1.read()
today_string
# Out:
# '04/08/2021'

# %% [markdown]
# ### 3. Parse the date from today_string.

# %% [markdown]
# **Ans:**

# %%
from datetime import datetime

datetime_object = datetime.strptime(today_string, '%m/%d/%Y')
print(datetime_object)
print(datetime_object.day)
# Out:
# 2021-04-08 00:00:00
# 8

# %% [markdown]
# ### 4. List the files in your current directory

# %% [markdown]
# **Ans:**

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Assignment_21.ipynb', 'today.txt']

# %% [markdown]
# ### 5. Create a list of all of the files in your parent directory (minimum five files should be available).

# %% [markdown]
# **Ans:**

# %%
os.listdir("../")
# Out:
# ['Assignment', 'CV', 'DL', 'ML', 'NLP', 'Python']

# %% [markdown]
# ### 6. Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %% [markdown]
# **Ans:**

# %% [markdown]
# ### 7. Create a date object of your day of birth.

# %% [markdown]
# **Ans:**

# %%
import datetime
date = datetime.datetime(1996, 4, 1)
date
# Out:
# datetime.datetime(1996, 4, 1, 0, 0)

# %% [markdown]
# ### 8. What day of the week was your day of birth?

# %% [markdown]
# **Ans:**

# %%
import calendar
calendar.day_name[date.weekday()]
# Out:
# 'Monday'

# %% [markdown]
# ### 9. When will you be (or when were you) 10,000 days old?

# %% [markdown]
# **Ans:**

# %%
new_date = date + datetime.timedelta(days=10000)
new_date
# Out:
# datetime.datetime(2023, 8, 18, 0, 0)
